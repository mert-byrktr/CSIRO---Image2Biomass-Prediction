# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
DATA_PATH = kagglehub.competition_download('csiro-biomass')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/csiro-biomass...
# 100%|██████████| 1.02G/1.02G [00:46<00:00, 23.4MB/s]
# Extracting files...
# Data source import complete.

# %%
# !pip install torch==2.6.0 -qq
# !pip install torchvision==0.21.0 -qq
# !pip install timm==1.0.19 -qq
# !pip install albumentations==2.0.8 -qq

# %%
import os, random, math
from dataclasses import dataclass
from typing import Dict, List, Optional

import numpy as np
import pandas as pd
from PIL import Image

import cv2
import albumentations as A
from albumentations.pytorch import ToTensorV2

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import GroupKFold, StratifiedGroupKFold

import timm
import torchvision
from torchvision import transforms

# %%
print(pd.__version__)
print(np.__version__)
print(torch.__version__)
print(torchvision.__version__)
print(timm.__version__)
print(A.__version__)
# Out:
# 2.2.2
# 2.0.2
# 2.9.0+cu126
# 0.24.0+cu126
# 1.0.24
# 2.0.8

# %%
train_dir = os.path.join(DATA_PATH, 'train')
test_dir = os.path.join(DATA_PATH, 'test')

# %%
train_df = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'))
train_df.head(10)
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
# 5  ID1012260530__Dry_Clover_g  train/ID1012260530.jpg      2015/4/1   NSW
# 6    ID1012260530__Dry_Dead_g  train/ID1012260530.jpg      2015/4/1   NSW
# 7   ID1012260530__Dry_Green_g  train/ID1012260530.jpg      2015/4/1   NSW
# 8   ID1012260530__Dry_Total_g  train/ID1012260530.jpg      2015/4/1   NSW
# 9         ID1012260530__GDM_g  train/ID1012260530.jpg      2015/4/1   NSW
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
# 5          Lucerne           0.55        16.0000  Dry_Clover_g   0.0000
# 6          Lucerne           0.55        16.0000    Dry_Dead_g   0.0000
# 7          Lucerne           0.55        16.0000   Dry_Green_g   7.6000
# 8          Lucerne           0.55        16.0000   Dry_Total_g   7.6000
# 9          Lucerne           0.55        16.0000         GDM_g   7.6000

# %%
for col in train_df.columns:
    print(col, train_df[col].nunique())
# Out:
# sample_id 1785
# image_path 357
# Sampling_Date 28
# State 4
# Species 15
# Pre_GSHH_NDVI 65
# Height_Ave_cm 81
# target_name 5
# target 1328

# %%
train_df.Species.value_counts()
# Out:
# Species
# Ryegrass_Clover                                                490
# Ryegrass                                                       310
# Phalaris_Clover                                                210
# Clover                                                         205
# Fescue                                                         140
# Lucerne                                                        110
# Phalaris_BarleyGrass_SilverGrass_SpearGrass_Clover_Capeweed     55
# Fescue_CrumbWeed                                                50
# WhiteClover                                                     50
# Phalaris                                                        40
# Phalaris_Ryegrass_Clover                                        40
# Phalaris_Clover_Ryegrass_Barleygrass_Bromegrass                 35
# SubcloverLosa                                                   25
# SubcloverDalkeith                                               15
# Mixed                                                           10
# Name: count, dtype: int64

# %%
train_df.State.value_counts()
# Out:
# State
# Tas    690
# Vic    560
# NSW    375
# WA     160
# Name: count, dtype: int64

# %%
len(train_df)
# Out:
# 1785

# %%
train_df['Sampling_Date'] = pd.to_datetime(train_df['Sampling_Date'])
train_df.Sampling_Date.max(), train_df.Sampling_Date.min()
# Out:
# (Timestamp('2015-11-10 00:00:00'), Timestamp('2015-01-15 00:00:00'))

# %%
train_df['Year'] = train_df['Sampling_Date'].dt.year
train_df['Month'] = train_df['Sampling_Date'].dt.month

train_df.Year.value_counts(), train_df.Month.value_counts()
# Out:
# (Year
#  2015    1785
#  Name: count, dtype: int64,
#  Month
#  9     335
#  6     265
#  5     210
#  7     205
#  8     185
#  11    185
#  10    145
#  2     120
#  1      85
#  4      50
#  Name: count, dtype: int64)

# %%
aa = train_df[train_df.State=="NSW"]["Month"]
aa.value_counts()
# Out:
# Month
# 2     120
# 1      85
# 5      65
# 10     55
# 4      50
# Name: count, dtype: int64

# %%
train_df["SeasonQ"] = train_df["Sampling_Date"].dt.to_period("Q").astype(str)
train_df["SeasonQ"].value_counts()
# Out:
# SeasonQ
# 2015Q3    725
# 2015Q2    525
# 2015Q4    330
# 2015Q1    205
# Name: count, dtype: int64

# %%
from dataclasses import dataclass, asdict

# %%
@dataclass
class CFG:
    CSV_PATH: str = DATA_PATH + "/train.csv"
    IMG_ROOT: str = DATA_PATH + ""  # keep as you had
    MODEL_NAME: str = "vit_base_patch14_dinov2.lvd142m"  # DINOv2 in timm
    IMG_SIZE: int = 518
    N_FOLDS: int = 5
    EPOCHS: int = 40
    BATCH_SIZE: int = 32
    NUM_WORKERS: int = 4

    LR_HEAD: float = 6e-4
    LR_BACKBONE: float = 6e-5
    # LR_HEAD: float = 1.2e-3
    # LR_BACKBONE: float = 1.2e-4
    WEIGHT_DECAY: float = 0.05

    SEED: int = 42
    DEVICE: str = "cuda" if torch.cuda.is_available() else "cpu"

    SAVE_DIR: str = "model_outputs"

    USE_TILING: bool = True
    TILES_TRAIN: Optional[int] = 2
    TILES_VAL: Optional[int] = None

    FREEZE_EPOCHS: int = 3
    UNFREEZE_LAST_N_BLOCKS: int = 2

    TARGET_ORDER = ["Dry_Green_g", "Dry_Dead_g", "Dry_Clover_g", "GDM_g", "Dry_Total_g"]
    LOSS_WEIGHTS = {
        "Dry_Green_g": 0.1,
        "Dry_Dead_g": 0.1,
        "Dry_Clover_g": 0.1,
        "GDM_g": 0.2,
        "Dry_Total_g": 0.5
    }

    EMA_ENABLED: bool = True
    EMA_DECAY: float = 0.99
    EMA_WARMUP_STEPS: int = 200
    EMA_ON_CPU: bool = False

cfg_inst = CFG()

# %%
def seed_everything(seed: int = CFG.SEED):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

def split_1x2_lr(img):
    h, w = img.shape[:2]
    w2 = w // 2
    return [img[:, :w2], img[:, w2:]]

def split_2x1_tb(img):
    h, w = img.shape[:2]
    h2 = h // 2
    return [img[:h2, :], img[h2:, :]]

# %%
from copy import deepcopy

class ModelEMA:

    def __init__(self, model: nn.Module, decay: float = 0.999, device: str | None = None, warmup_steps: int = 0):
        self.ema = deepcopy(model).eval()
        for p in self.ema.parameters():
            p.requires_grad_(False)

        self.decay = decay
        self.warmup_steps = warmup_steps
        self.num_updates = 0

        if device is not None:
            self.ema.to(device)

    @torch.no_grad()
    def update(self, model: nn.Module):
        self.num_updates += 1

        if self.warmup_steps and self.num_updates < self.warmup_steps:
            d = 1.0 - (1.0 - self.decay) * (self.num_updates / self.warmup_steps)
        else:
            d = self.decay

        msd = model.state_dict()
        esd = self.ema.state_dict()

        for k, v in esd.items():
            mv = msd[k].detach()
            if v.dtype.is_floating_point:
                v.mul_(d).add_(mv, alpha=(1.0 - d))
            else:
                v.copy_(mv)

# %%
class PastureDataset(Dataset):
    def __init__(self, df_wide: pd.DataFrame, transforms_img=None, use_tiling=True, tiles_train: Optional[int]=2,
                 split_mode: str = "tb"):
        self.df = df_wide.reset_index(drop=True)
        self.transforms = transforms_img
        self.use_tiling = use_tiling
        self.tiles_train = tiles_train
        self.split_mode = split_mode  # "tb" or "lr"

    def __len__(self):
        return int(len(self.df))

    def __getitem__(self, idx: int):
        row = self.df.iloc[idx]
        img_path = os.path.join(CFG.IMG_ROOT, row["image_path"])

        image = cv2.imread(img_path)
        if image is None:
            raise FileNotFoundError(f"Image not found: {img_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        targets = np.array([row[t] for t in CFG.TARGET_ORDER], dtype=np.float32)
        y = torch.tensor(np.log1p(targets), dtype=torch.float32)

        if not self.use_tiling:
            if self.transforms:
                image = self.transforms(image=image)["image"]
            return image, y

        if self.split_mode == "tb":
            tiles = split_2x1_tb(image)
        elif self.split_mode == "lr":
            tiles = split_1x2_lr(image)
        else:
            raise ValueError("split_mode must be 'tb' or 'lr'")

        tiles_total = len(tiles)

        if self.tiles_train is not None and self.tiles_train < tiles_total:
            idxs = np.random.choice(tiles_total, self.tiles_train, replace=False)
            tiles = [tiles[i] for i in idxs]

        tile_tensors = []
        for timg in tiles:
            if self.transforms:
                timg = self.transforms(image=timg)["image"]
            else:
                timg = torch.from_numpy(timg).permute(2, 0, 1).float()
            tile_tensors.append(timg)

        x = torch.stack(tile_tensors, dim=0)
        return x, y


def build_transforms(train: bool = True):
    if train:
        return A.Compose([

            A.Resize(CFG.IMG_SIZE, CFG.IMG_SIZE),

            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=180, p=0.7),

            A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
            # A.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=20, val_shift_limit=10, p=0.4),

            A.RandomSnow(p=0.1),
            A.RandomShadow(p=0.1),
            A.RandomFog(p=0.1),
            A.RandomRain(p=0.1),
            A.RandomSunFlare(p=0.1),
            # A.RandomGravel(p=0.1),

            A.CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=0.2),

            A.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
            A.ToTensorV2(),
        ],
      seed=42)
    else:
        return A.Compose([
            A.Resize(CFG.IMG_SIZE, CFG.IMG_SIZE),
            A.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
            A.ToTensorV2(),
        ],
      seed=42)


class DinoV2TileRegressor(nn.Module):
    def __init__(self, model_name=CFG.MODEL_NAME, out_dim=5, dropout=0.2, pretrained=True):
        super().__init__()
        self.backbone = timm.create_model(model_name, pretrained=pretrained, num_classes=0, dynamic_img_size=True)
        d = self.backbone.num_features
        self.drop = nn.Dropout(dropout)
        self.head = nn.Linear(d, out_dim)

    def forward(self, x):
        if x.dim() == 4:
            feat = self.backbone(x)
            return self.head(self.drop(feat))

        B, T, C, H, W = x.shape
        x = x.reshape(B*T, C, H, W)
        feat = self.backbone(x).reshape(B, T, -1).mean(dim=1)
        return self.head(self.drop(feat))


class WeightedMSE(nn.Module):
    def __init__(self, target_order: List[str], weights: Dict[str, float]):
        super().__init__()
        self.idx = {t:i for i,t in enumerate(target_order)}
        self.w = torch.tensor([weights[t] for t in target_order], dtype=torch.float32)

    def forward(self, pred: torch.Tensor, y: torch.Tensor):
        diff2 = (pred - y) ** 2
        w = self.w.to(pred.device)
        return (diff2 * w).mean()

class WeightedHuberLoss(nn.Module):
    def __init__(self, target_order, weights, delta=1.0):
        super().__init__()
        self.weights = torch.tensor([weights[t] for t in target_order]).cuda()
        self.huber = nn.HuberLoss(reduction='none', delta=delta)

    def forward(self, pred, y):
        loss = self.huber(pred, y)
        return (loss * self.weights).mean()


def r2_per_target(y_true: np.ndarray, y_pred: np.ndarray) -> Dict[str, float]:

    out = {}
    for i, t in enumerate(CFG.TARGET_ORDER):
        yt = y_true[:, i]
        yp = y_pred[:, i]
        ss_res = np.sum((yt - yp) ** 2)
        ss_tot = np.sum((yt - yt.mean()) ** 2) + 1e-12
        out[t] = 1.0 - (ss_res / ss_tot)
    return out


def weighted_r2(r2_dict: Dict[str, float]) -> float:
    return sum(CFG.LOSS_WEIGHTS[t] * r2_dict[t] for t in CFG.TARGET_ORDER)


def global_weighted_r2(y_true_mat: np.ndarray,
                       y_pred_mat: np.ndarray,
                       weights: Dict[str, float],
                       order: List[str]) -> float:

    w_cols = np.array([weights[t] for t in order], dtype=np.float64)
    W = np.broadcast_to(w_cols, y_true_mat.shape).astype(np.float64)

    y_true = y_true_mat.astype(np.float64).ravel()
    y_pred = y_pred_mat.astype(np.float64).ravel()
    w_flat = W.ravel()

    y_bar = np.sum(w_flat * y_true) / np.sum(w_flat)

    ss_res = np.sum(w_flat * (y_true - y_pred) ** 2)
    ss_tot = np.sum(w_flat * (y_true - y_bar) ** 2) + 1e-12

    return 1.0 - (ss_res / ss_tot)

# %%
def train_one_epoch(model, loader, optimizer, criterion, scheduler=None, ema: ModelEMA | None = None):
    model.train()
    running_loss = 0.0

    for images, targets in loader:
        images = images.to(CFG.DEVICE, non_blocking=True)
        targets = targets.to(CFG.DEVICE, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        preds = model(images)
        loss = criterion(preds, targets)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        if ema is not None:
            ema.update(model)

        if scheduler is not None:
            scheduler.step()

        running_loss += loss.item() * targets.size(0)

    return running_loss / len(loader.dataset)


@torch.no_grad()
def validate(model, loader, return_arrays: bool = False):
    model.eval()
    all_preds, all_tgts = [], []

    for images, targets in loader:
        images = images.to(CFG.DEVICE, non_blocking=True)
        preds = model(images)

        preds = torch.expm1(preds)
        targets = torch.expm1(targets)

        all_preds.append(preds.cpu().numpy())
        all_tgts.append(targets.cpu().numpy())

    all_preds = np.concatenate(all_preds, axis=0)
    all_tgts  = np.concatenate(all_tgts, axis=0)

    gw_r2 = global_weighted_r2(all_tgts, all_preds, CFG.LOSS_WEIGHTS, CFG.TARGET_ORDER)
    r2_dict = r2_per_target(all_tgts, all_preds)

    if return_arrays:
        return gw_r2, r2_dict, all_preds, all_tgts
    return gw_r2, r2_dict

# %%
def freeze_backbone(model: DinoV2TileRegressor):
    for p in model.backbone.parameters():
        p.requires_grad = False

def unfreeze_last_blocks(model: DinoV2TileRegressor, last_n: int = 2):
    freeze_backbone(model)
    if hasattr(model.backbone, "blocks"):
        for b in model.backbone.blocks[-last_n:]:
            for p in b.parameters():
                p.requires_grad = True
    for p in model.head.parameters():
        p.requires_grad = True
    for p in model.drop.parameters():
        p.requires_grad = True

def build_optimizer(model: DinoV2TileRegressor, lr_head: float, lr_backbone: float, wd: float):
    param_groups = []
    bb_params = [p for p in model.backbone.parameters() if p.requires_grad]
    if bb_params:
        param_groups.append({"params": bb_params, "lr": lr_backbone})
    param_groups.append({"params": model.head.parameters(), "lr": lr_head})
    return torch.optim.AdamW(param_groups, weight_decay=wd)

# %%
def run_fold(fold_id: int, df_wide: pd.DataFrame):
    print(f"\n========== Fold {fold_id + 1} / {CFG.N_FOLDS} ==========")

    trn_df = df_wide[df_wide["fold"] != fold_id].reset_index(drop=True)
    val_df = df_wide[df_wide["fold"] == fold_id].reset_index(drop=True)

    train_ds = PastureDataset(
        trn_df, transforms_img=build_transforms(train=True),
        use_tiling=CFG.USE_TILING, tiles_train=CFG.TILES_TRAIN, split_mode="lr"
    )
    val_ds = PastureDataset(
        val_df, transforms_img=build_transforms(train=False),
        use_tiling=CFG.USE_TILING, tiles_train=CFG.TILES_VAL, split_mode="lr"
    )

    g = torch.Generator(); g.manual_seed(CFG.SEED)

    train_loader = DataLoader(
        train_ds, batch_size=CFG.BATCH_SIZE, shuffle=True,
        num_workers=CFG.NUM_WORKERS, pin_memory=True, drop_last=True,
        worker_init_fn=worker_init_fn, generator=g
    )
    val_loader = DataLoader(
        val_ds, batch_size=CFG.BATCH_SIZE * 2, shuffle=False,
        num_workers=CFG.NUM_WORKERS, pin_memory=True,
        worker_init_fn=worker_init_fn, generator=g
    )

    model = DinoV2TileRegressor(model_name=CFG.MODEL_NAME, out_dim=len(CFG.TARGET_ORDER), pretrained=True).to(CFG.DEVICE)

    ema = None
    if getattr(CFG, "EMA_ENABLED", False):
        ema_device = "cpu" if getattr(CFG, "EMA_ON_CPU", False) else CFG.DEVICE
        ema = ModelEMA(model, decay=CFG.EMA_DECAY, device=ema_device, warmup_steps=getattr(CFG, "EMA_WARMUP_STEPS", 0))

    criterion = WeightedHuberLoss(CFG.TARGET_ORDER, CFG.LOSS_WEIGHTS, delta=1.0)

    freeze_backbone(model)
    optimizer = build_optimizer(model, lr_head=CFG.LR_HEAD, lr_backbone=0.0, wd=CFG.WEIGHT_DECAY)
    total_steps = CFG.EPOCHS * len(train_loader)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_steps, eta_min=1e-6)

    best_wr2 = -1e9

    for epoch in range(1, CFG.EPOCHS + 1):

        if epoch == CFG.FREEZE_EPOCHS + 1:
            unfreeze_last_blocks(model, last_n=CFG.UNFREEZE_LAST_N_BLOCKS)
            optimizer = build_optimizer(model, lr_head=CFG.LR_HEAD * 0.7, lr_backbone=CFG.LR_BACKBONE, wd=CFG.WEIGHT_DECAY)
            remaining_steps = (CFG.EPOCHS - epoch + 1) * len(train_loader)
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max(1, remaining_steps), eta_min=1e-6)

        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, scheduler, ema=ema)

        eval_model = ema.ema.to(CFG.DEVICE) if ema is not None else model
        wr2, r2d = validate(eval_model, val_loader)

        best_wr2 = max(best_wr2, wr2)
        print(
            f"Epoch {epoch:02d}/{CFG.EPOCHS} | train_loss={tr_loss:.4f} | "
            f"val_gwR2={wr2:.4f} | " +
            ", ".join([f"{k}:{v:.3f}" for k, v in r2d.items()])
        )

    eval_model = ema.ema.to(CFG.DEVICE) if ema is not None else model
    fold_wr2, fold_r2d, fold_preds, fold_tgts = validate(eval_model, val_loader, return_arrays=True)
    print(f"[Fold {fold_id + 1}] Final val global weighted R² = {fold_wr2:.4f}")

    os.makedirs(CFG.SAVE_DIR, exist_ok=True)
    final_path = os.path.join(CFG.SAVE_DIR, f"fold{fold_id}_final.pth")

    payload = {
        "model": model.state_dict(),
        "cfg": asdict(cfg_inst),
        "fold": fold_id + 1,
    }
    if ema is not None:
        payload["ema"] = ema.ema.state_dict()

    torch.save(payload, final_path)
    print(f"Saved final checkpoint: {final_path}")

    return fold_preds, fold_tgts, fold_wr2

# %%
train_df.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg    2015-09-04   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg    2015-09-04   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg    2015-09-04   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg    2015-09-04   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg    2015-09-04   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target  Year  \
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000  2015
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984  2015
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751  2015
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735  2015
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750  2015
#
#    Month SeasonQ
# 0      9  2015Q3
# 1      9  2015Q3
# 2      9  2015Q3
# 3      9  2015Q3
# 4      9  2015Q3

# %%
# def make_folds(df: pd.DataFrame) -> pd.DataFrame:

#     df = df.copy()
#     df["Sampling_Date"] = pd.to_datetime(df["Sampling_Date"], errors="coerce")

#     # df = df.sort_values("image_path").reset_index(drop=True)

#     meta = (
#         df
#         .drop_duplicates("image_path")
#         [["image_path", "State", "Sampling_Date"]]
#         .copy().reset_index(drop=True)
#     )

#     meta["date_group"] = meta["Sampling_Date"].astype(str)
#     meta["State"] = meta["State"].astype(str)

#     sgkf = StratifiedGroupKFold(n_splits=CFG.N_FOLDS, shuffle=True, random_state=CFG.SEED)
#     meta["fold"] = -1

#     for fold, (_, val_idx) in enumerate(sgkf.split(meta, y=meta["State"], groups=meta["date_group"])):
#         meta.loc[val_idx, "fold"] = fold

#     wide = df.pivot(index="image_path", columns="target_name", values="target").reset_index()

#     wide = wide[["image_path"] + CFG.TARGET_ORDER]
#     wide = wide.merge(meta[["image_path", "fold", "State", "date_group"]],
#                       on="image_path", how="left")
#     return wide


def make_folds(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    df["Sampling_Date"] = pd.to_datetime(df["Sampling_Date"], errors="coerce")

    meta = (
        df
        .drop_duplicates("image_path")
        [["image_path", "State", "Sampling_Date", "Height_Ave_cm", "Pre_GSHH_NDVI"]]
        .copy()
        .reset_index(drop=True)
    )

    wide = df.pivot(index="image_path", columns="target_name", values="target").reset_index()

    wide = wide.merge(meta, on="image_path", how="left")

    wide["day"] = wide["Sampling_Date"].dt.day
    wide["month"] = wide["Sampling_Date"].dt.month

    wide["group_key"] = (
        wide["day"].astype(str) + '/' +
        wide["month"].astype(str) + '_' +
        wide["State"].astype(str)
    )

    clover_present = (wide["Dry_Clover_g"].fillna(0) > 0).astype(int).astype(str)
    dead_present   = (wide["Dry_Dead_g"].fillna(0) > 0).astype(int).astype(str)

    wide["stratify_col"] = clover_present + '_' + dead_present
    sgkf = StratifiedGroupKFold(n_splits=CFG.N_FOLDS, shuffle=True, random_state=CFG.SEED)
    wide["fold"] = -1

    for fold, (_, val_idx) in enumerate(sgkf.split(wide, y=wide["stratify_col"], groups=wide["group_key"])):
        wide.loc[val_idx, "fold"] = fold

    cols_to_keep = ["image_path"] + CFG.TARGET_ORDER + ["fold", "State", "Height_Ave_cm", "Pre_GSHH_NDVI", "group_key"]
    return wide[cols_to_keep]

# %%
gseed_everything(CFG.SEED)

train = pd.read_csv(CFG.CSV_PATH)
train_wide = make_folds(train)

print(f'DF VALUE COUNTS: {train_wide["fold"].value_counts()}')
for f in sorted(train_wide["fold"].unique()):
    val = train_wide[train_wide["fold"] == f]
    trn = train_wide[train_wide["fold"] != f]
    print(f"Fold {f}: val={len(val)}, train={len(trn)}, sum={len(val)+len(trn)}")

oof_preds_list, oof_tgts_list, fold_gwr2_list = [], [], []

print("\n=== Training ===\n")
for fold in range(CFG.N_FOLDS):
    preds, tgts, fold_gwr2 = run_fold(fold, train_wide)
    oof_preds_list.append(preds)
    oof_tgts_list.append(tgts)
    fold_gwr2_list.append(fold_gwr2)
    print(f"Fold {fold} weighted R² = {fold_gwr2:.4f}")

OOF_PRED = np.concatenate(oof_preds_list, axis=0)
OOF_TRUE = np.concatenate(oof_tgts_list, axis=0)

oof_gw_r2 = global_weighted_r2(OOF_TRUE, OOF_PRED, CFG.LOSS_WEIGHTS, CFG.TARGET_ORDER)
oof_r2 = r2_per_target(OOF_TRUE, OOF_PRED)
mean_wr2 = float(np.mean(fold_gwr2_list))

print(f"\nAverage weighted R²: {mean_wr2:.4f}")
print(f"\nOverall OOF Global Weighted R²: {oof_gw_r2:.4f}\n")
print("Per-target OOF R²:")
for k, v in oof_r2.items():
    print(f"{k}: {v:.4f}")
# Out:
# DF VALUE COUNTS: fold
# 2    85
# 3    76
# 4    69
# 1    68
# 0    59
# Name: count, dtype: int64
# Fold 0: val=59, train=298, sum=357
# Fold 1: val=68, train=289, sum=357
# Fold 2: val=85, train=272, sum=357
# Fold 3: val=76, train=281, sum=357
# Fold 4: val=69, train=288, sum=357
#
# === Training ===
#
#
# ========== Fold 1 / 5 ==========
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Epoch 01/40 | train_loss=0.2833 | val_gwR2=-1.4994 | Dry_Green_g:-1.900, Dry_Dead_g:-1.044, Dry_Clover_g:-0.145, GDM_g:-1.835, Dry_Total_g:-3.118
# Epoch 02/40 | train_loss=0.1012 | val_gwR2=-1.4976 | Dry_Green_g:-1.899, Dry_Dead_g:-1.041, Dry_Clover_g:-0.144, GDM_g:-1.832, Dry_Total_g:-3.116
# Epoch 03/40 | train_loss=0.0680 | val_gwR2=-1.4943 | Dry_Green_g:-1.898, Dry_Dead_g:-1.035, Dry_Clover_g:-0.143, GDM_g:-1.824, Dry_Total_g:-3.111
# Epoch 04/40 | train_loss=0.2769 | val_gwR2=-1.4839 | Dry_Green_g:-1.895, Dry_Dead_g:-1.028, Dry_Clover_g:-0.140, GDM_g:-1.806, Dry_Total_g:-3.095
# Epoch 05/40 | train_loss=0.0863 | val_gwR2=-1.4693 | Dry_Green_g:-1.892, Dry_Dead_g:-1.017, Dry_Clover_g:-0.134, GDM_g:-1.775, Dry_Total_g:-3.074
# Epoch 06/40 | train_loss=0.0557 | val_gwR2=-1.4484 | Dry_Green_g:-1.887, Dry_Dead_g:-1.000, Dry_Clover_g:-0.127, GDM_g:-1.732, Dry_Total_g:-3.044
# Epoch 07/40 | train_loss=0.0525 | val_gwR2=-1.4174 | Dry_Green_g:-1.878, Dry_Dead_g:-0.971, Dry_Clover_g:-0.116, GDM_g:-1.668, Dry_Total_g:-3.001
# Epoch 08/40 | train_loss=0.0461 | val_gwR2=-1.3783 | Dry_Green_g:-1.865, Dry_Dead_g:-0.935, Dry_Clover_g:-0.099, GDM_g:-1.585, Dry_Total_g:-2.946
# Epoch 09/40 | train_loss=0.0356 | val_gwR2=-1.3277 | Dry_Green_g:-1.847, Dry_Dead_g:-0.890, Dry_Clover_g:-0.077, GDM_g:-1.476, Dry_Total_g:-2.877
# Epoch 10/40 | train_loss=0.0318 | val_gwR2=-1.2598 | Dry_Green_g:-1.821, Dry_Dead_g:-0.838, Dry_Clover_g:-0.044, GDM_g:-1.335, Dry_Total_g:-2.783
# Epoch 11/40 | train_loss=0.0288 | val_gwR2=-1.1753 | Dry_Green_g:-1.786, Dry_Dead_g:-0.775, Dry_Clover_g:0.000, GDM_g:-1.169, Dry_Total_g:-2.661
# Epoch 12/40 | train_loss=0.0247 | val_gwR2=-1.0719 | Dry_Green_g:-1.737, Dry_Dead_g:-0.705, Dry_Clover_g:0.061, GDM_g:-0.972, Dry_Total_g:-2.511
# Epoch 13/40 | train_loss=0.0232 | val_gwR2=-0.9530 | Dry_Green_g:-1.670, Dry_Dead_g:-0.631, Dry_Clover_g:0.130, GDM_g:-0.760, Dry_Total_g:-2.334
# Epoch 14/40 | train_loss=0.0237 | val_gwR2=-0.8115 | Dry_Green_g:-1.586, Dry_Dead_g:-0.557, Dry_Clover_g:0.216, GDM_g:-0.527, Dry_Total_g:-2.117
# Epoch 15/40 | train_loss=0.0219 | val_gwR2=-0.6547 | Dry_Green_g:-1.478, Dry_Dead_g:-0.484, Dry_Clover_g:0.309, GDM_g:-0.289, Dry_Total_g:-1.870
# Epoch 16/40 | train_loss=0.0237 | val_gwR2=-0.4916 | Dry_Green_g:-1.355, Dry_Dead_g:-0.420, Dry_Clover_g:0.402, GDM_g:-0.076, Dry_Total_g:-1.599
# Epoch 17/40 | train_loss=0.0182 | val_gwR2=-0.3188 | Dry_Green_g:-1.209, Dry_Dead_g:-0.366, Dry_Clover_g:0.494, GDM_g:0.110, Dry_Total_g:-1.299
# Epoch 18/40 | train_loss=0.0177 | val_gwR2=-0.1512 | Dry_Green_g:-1.053, Dry_Dead_g:-0.336, Dry_Clover_g:0.578, GDM_g:0.264, Dry_Total_g:-0.997
# Epoch 19/40 | train_loss=0.0165 | val_gwR2=0.0158 | Dry_Green_g:-0.883, Dry_Dead_g:-0.320, Dry_Clover_g:0.663, GDM_g:0.396, Dry_Total_g:-0.691
# Epoch 20/40 | train_loss=0.0162 | val_gwR2=0.1695 | Dry_Green_g:-0.711, Dry_Dead_g:-0.315, Dry_Clover_g:0.739, GDM_g:0.504, Dry_Total_g:-0.406
# Epoch 21/40 | train_loss=0.0161 | val_gwR2=0.3000 | Dry_Green_g:-0.536, Dry_Dead_g:-0.322, Dry_Clover_g:0.803, GDM_g:0.578, Dry_Total_g:-0.162
# Epoch 22/40 | train_loss=0.0142 | val_gwR2=0.4181 | Dry_Green_g:-0.359, Dry_Dead_g:-0.333, Dry_Clover_g:0.851, GDM_g:0.641, Dry_Total_g:0.056
# Epoch 23/40 | train_loss=0.0158 | val_gwR2=0.5125 | Dry_Green_g:-0.198, Dry_Dead_g:-0.336, Dry_Clover_g:0.875, GDM_g:0.685, Dry_Total_g:0.231
# Epoch 24/40 | train_loss=0.0162 | val_gwR2=0.5877 | Dry_Green_g:-0.044, Dry_Dead_g:-0.336, Dry_Clover_g:0.885, GDM_g:0.712, Dry_Total_g:0.368
# Epoch 25/40 | train_loss=0.0157 | val_gwR2=0.6396 | Dry_Green_g:0.071, Dry_Dead_g:-0.337, Dry_Clover_g:0.884, GDM_g:0.727, Dry_Total_g:0.463
# Epoch 26/40 | train_loss=0.0145 | val_gwR2=0.6773 | Dry_Green_g:0.163, Dry_Dead_g:-0.346, Dry_Clover_g:0.867, GDM_g:0.735, Dry_Total_g:0.532
# Epoch 27/40 | train_loss=0.0141 | val_gwR2=0.7039 | Dry_Green_g:0.250, Dry_Dead_g:-0.350, Dry_Clover_g:0.849, GDM_g:0.739, Dry_Total_g:0.577
# Epoch 28/40 | train_loss=0.0138 | val_gwR2=0.7253 | Dry_Green_g:0.319, Dry_Dead_g:-0.344, Dry_Clover_g:0.832, GDM_g:0.742, Dry_Total_g:0.613
# Epoch 29/40 | train_loss=0.0127 | val_gwR2=0.7414 | Dry_Green_g:0.389, Dry_Dead_g:-0.340, Dry_Clover_g:0.815, GDM_g:0.741, Dry_Total_g:0.639
# Epoch 30/40 | train_loss=0.0121 | val_gwR2=0.7509 | Dry_Green_g:0.436, Dry_Dead_g:-0.339, Dry_Clover_g:0.785, GDM_g:0.739, Dry_Total_g:0.653
# Epoch 31/40 | train_loss=0.0124 | val_gwR2=0.7576 | Dry_Green_g:0.471, Dry_Dead_g:-0.333, Dry_Clover_g:0.767, GDM_g:0.738, Dry_Total_g:0.663
# Epoch 32/40 | train_loss=0.0124 | val_gwR2=0.7626 | Dry_Green_g:0.499, Dry_Dead_g:-0.330, Dry_Clover_g:0.743, GDM_g:0.738, Dry_Total_g:0.670
# Epoch 33/40 | train_loss=0.0114 | val_gwR2=0.7659 | Dry_Green_g:0.529, Dry_Dead_g:-0.326, Dry_Clover_g:0.721, GDM_g:0.737, Dry_Total_g:0.673
# Epoch 34/40 | train_loss=0.0123 | val_gwR2=0.7677 | Dry_Green_g:0.551, Dry_Dead_g:-0.324, Dry_Clover_g:0.688, GDM_g:0.735, Dry_Total_g:0.675
# Epoch 35/40 | train_loss=0.0120 | val_gwR2=0.7686 | Dry_Green_g:0.571, Dry_Dead_g:-0.321, Dry_Clover_g:0.653, GDM_g:0.733, Dry_Total_g:0.674
# Epoch 36/40 | train_loss=0.0118 | val_gwR2=0.7689 | Dry_Green_g:0.590, Dry_Dead_g:-0.310, Dry_Clover_g:0.614, GDM_g:0.732, Dry_Total_g:0.673
# Epoch 37/40 | train_loss=0.0109 | val_gwR2=0.7681 | Dry_Green_g:0.600, Dry_Dead_g:-0.302, Dry_Clover_g:0.563, GDM_g:0.731, Dry_Total_g:0.670
# Epoch 38/40 | train_loss=0.0104 | val_gwR2=0.7673 | Dry_Green_g:0.610, Dry_Dead_g:-0.297, Dry_Clover_g:0.520, GDM_g:0.731, Dry_Total_g:0.668
# Epoch 39/40 | train_loss=0.0113 | val_gwR2=0.7665 | Dry_Green_g:0.620, Dry_Dead_g:-0.292, Dry_Clover_g:0.482, GDM_g:0.730, Dry_Total_g:0.665
# Epoch 40/40 | train_loss=0.0110 | val_gwR2=0.7656 | Dry_Green_g:0.630, Dry_Dead_g:-0.286, Dry_Clover_g:0.449, GDM_g:0.729, Dry_Total_g:0.662
# [Fold 1] Final val global weighted R² = 0.7656
# Saved final checkpoint: model_outputs/fold0_final.pth
# Fold 0 weighted R² = 0.7656
#
# ========== Fold 2 / 5 ==========
# Epoch 01/40 | train_loss=0.2897 | val_gwR2=-1.1577 | Dry_Green_g:-0.718, Dry_Dead_g:-0.594, Dry_Clover_g:-0.492, GDM_g:-2.055, Dry_Total_g:-1.816
# Epoch 02/40 | train_loss=0.1358 | val_gwR2=-1.1558 | Dry_Green_g:-0.715, Dry_Dead_g:-0.592, Dry_Clover_g:-0.491, GDM_g:-2.054, Dry_Total_g:-1.814
# Epoch 03/40 | train_loss=0.0893 | val_gwR2=-1.1531 | Dry_Green_g:-0.707, Dry_Dead_g:-0.589, Dry_Clover_g:-0.490, GDM_g:-2.052, Dry_Total_g:-1.811
# Epoch 04/40 | train_loss=0.1875 | val_gwR2=-1.1468 | Dry_Green_g:-0.703, Dry_Dead_g:-0.583, Dry_Clover_g:-0.489, GDM_g:-2.043, Dry_Total_g:-1.802
# Epoch 05/40 | train_loss=0.0714 | val_gwR2=-1.1370 | Dry_Green_g:-0.691, Dry_Dead_g:-0.572, Dry_Clover_g:-0.488, GDM_g:-2.032, Dry_Total_g:-1.790
# Epoch 06/40 | train_loss=0.0486 | val_gwR2=-1.1226 | Dry_Green_g:-0.677, Dry_Dead_g:-0.554, Dry_Clover_g:-0.486, GDM_g:-2.014, Dry_Total_g:-1.771
# Epoch 07/40 | train_loss=0.0390 | val_gwR2=-1.1011 | Dry_Green_g:-0.661, Dry_Dead_g:-0.527, Dry_Clover_g:-0.482, GDM_g:-1.988, Dry_Total_g:-1.742
# Epoch 08/40 | train_loss=0.0348 | val_gwR2=-1.0700 | Dry_Green_g:-0.637, Dry_Dead_g:-0.489, Dry_Clover_g:-0.475, GDM_g:-1.951, Dry_Total_g:-1.700
# Epoch 09/40 | train_loss=0.0303 | val_gwR2=-1.0272 | Dry_Green_g:-0.606, Dry_Dead_g:-0.440, Dry_Clover_g:-0.466, GDM_g:-1.897, Dry_Total_g:-1.643
# Epoch 10/40 | train_loss=0.0267 | val_gwR2=-0.9691 | Dry_Green_g:-0.573, Dry_Dead_g:-0.384, Dry_Clover_g:-0.452, GDM_g:-1.823, Dry_Total_g:-1.564
# Epoch 11/40 | train_loss=0.0259 | val_gwR2=-0.8930 | Dry_Green_g:-0.525, Dry_Dead_g:-0.320, Dry_Clover_g:-0.432, GDM_g:-1.728, Dry_Total_g:-1.460
# Epoch 12/40 | train_loss=0.0243 | val_gwR2=-0.8000 | Dry_Green_g:-0.464, Dry_Dead_g:-0.258, Dry_Clover_g:-0.404, GDM_g:-1.609, Dry_Total_g:-1.333
# Epoch 13/40 | train_loss=0.0230 | val_gwR2=-0.6913 | Dry_Green_g:-0.391, Dry_Dead_g:-0.190, Dry_Clover_g:-0.366, GDM_g:-1.468, Dry_Total_g:-1.186
# Epoch 14/40 | train_loss=0.0266 | val_gwR2=-0.5678 | Dry_Green_g:-0.328, Dry_Dead_g:-0.132, Dry_Clover_g:-0.313, GDM_g:-1.315, Dry_Total_g:-1.014
# Epoch 15/40 | train_loss=0.0216 | val_gwR2=-0.4361 | Dry_Green_g:-0.259, Dry_Dead_g:-0.073, Dry_Clover_g:-0.245, GDM_g:-1.153, Dry_Total_g:-0.831
# Epoch 16/40 | train_loss=0.0202 | val_gwR2=-0.2956 | Dry_Green_g:-0.182, Dry_Dead_g:-0.008, Dry_Clover_g:-0.160, GDM_g:-0.981, Dry_Total_g:-0.636
# Epoch 17/40 | train_loss=0.0194 | val_gwR2=-0.1596 | Dry_Green_g:-0.114, Dry_Dead_g:0.049, Dry_Clover_g:-0.064, GDM_g:-0.803, Dry_Total_g:-0.449
# Epoch 18/40 | train_loss=0.0180 | val_gwR2=-0.0291 | Dry_Green_g:-0.042, Dry_Dead_g:0.104, Dry_Clover_g:0.049, GDM_g:-0.634, Dry_Total_g:-0.271
# Epoch 19/40 | train_loss=0.0180 | val_gwR2=0.0889 | Dry_Green_g:0.022, Dry_Dead_g:0.157, Dry_Clover_g:0.159, GDM_g:-0.476, Dry_Total_g:-0.111
# Epoch 20/40 | train_loss=0.0166 | val_gwR2=0.1923 | Dry_Green_g:0.091, Dry_Dead_g:0.203, Dry_Clover_g:0.257, GDM_g:-0.327, Dry_Total_g:0.026
# Epoch 21/40 | train_loss=0.0152 | val_gwR2=0.2792 | Dry_Green_g:0.159, Dry_Dead_g:0.244, Dry_Clover_g:0.361, GDM_g:-0.193, Dry_Total_g:0.138
# Epoch 22/40 | train_loss=0.0159 | val_gwR2=0.3511 | Dry_Green_g:0.215, Dry_Dead_g:0.277, Dry_Clover_g:0.448, GDM_g:-0.074, Dry_Total_g:0.228
# Epoch 23/40 | train_loss=0.0147 | val_gwR2=0.4143 | Dry_Green_g:0.272, Dry_Dead_g:0.310, Dry_Clover_g:0.522, GDM_g:0.040, Dry_Total_g:0.305
# Epoch 24/40 | train_loss=0.0136 | val_gwR2=0.4674 | Dry_Green_g:0.318, Dry_Dead_g:0.334, Dry_Clover_g:0.584, GDM_g:0.129, Dry_Total_g:0.371
# Epoch 25/40 | train_loss=0.0145 | val_gwR2=0.5077 | Dry_Green_g:0.358, Dry_Dead_g:0.358, Dry_Clover_g:0.639, GDM_g:0.206, Dry_Total_g:0.418
# Epoch 26/40 | train_loss=0.0145 | val_gwR2=0.5444 | Dry_Green_g:0.396, Dry_Dead_g:0.379, Dry_Clover_g:0.677, GDM_g:0.270, Dry_Total_g:0.463
# Epoch 27/40 | train_loss=0.0144 | val_gwR2=0.5730 | Dry_Green_g:0.436, Dry_Dead_g:0.397, Dry_Clover_g:0.694, GDM_g:0.321, Dry_Total_g:0.496
# Epoch 28/40 | train_loss=0.0148 | val_gwR2=0.5989 | Dry_Green_g:0.473, Dry_Dead_g:0.406, Dry_Clover_g:0.710, GDM_g:0.383, Dry_Total_g:0.523
# Epoch 29/40 | train_loss=0.0145 | val_gwR2=0.6229 | Dry_Green_g:0.502, Dry_Dead_g:0.416, Dry_Clover_g:0.722, GDM_g:0.431, Dry_Total_g:0.550
# Epoch 30/40 | train_loss=0.0135 | val_gwR2=0.6384 | Dry_Green_g:0.530, Dry_Dead_g:0.418, Dry_Clover_g:0.723, GDM_g:0.466, Dry_Total_g:0.566
# Epoch 31/40 | train_loss=0.0129 | val_gwR2=0.6521 | Dry_Green_g:0.549, Dry_Dead_g:0.422, Dry_Clover_g:0.726, GDM_g:0.501, Dry_Total_g:0.581
# Epoch 32/40 | train_loss=0.0120 | val_gwR2=0.6664 | Dry_Green_g:0.568, Dry_Dead_g:0.425, Dry_Clover_g:0.724, GDM_g:0.527, Dry_Total_g:0.598
# Epoch 33/40 | train_loss=0.0120 | val_gwR2=0.6780 | Dry_Green_g:0.582, Dry_Dead_g:0.427, Dry_Clover_g:0.722, GDM_g:0.552, Dry_Total_g:0.611
# Epoch 34/40 | train_loss=0.0118 | val_gwR2=0.6865 | Dry_Green_g:0.597, Dry_Dead_g:0.428, Dry_Clover_g:0.719, GDM_g:0.573, Dry_Total_g:0.619
# Epoch 35/40 | train_loss=0.0116 | val_gwR2=0.6956 | Dry_Green_g:0.613, Dry_Dead_g:0.428, Dry_Clover_g:0.716, GDM_g:0.590, Dry_Total_g:0.630
# Epoch 36/40 | train_loss=0.0122 | val_gwR2=0.7025 | Dry_Green_g:0.625, Dry_Dead_g:0.428, Dry_Clover_g:0.713, GDM_g:0.606, Dry_Total_g:0.637
# Epoch 37/40 | train_loss=0.0128 | val_gwR2=0.7100 | Dry_Green_g:0.638, Dry_Dead_g:0.429, Dry_Clover_g:0.710, GDM_g:0.622, Dry_Total_g:0.645
# Epoch 38/40 | train_loss=0.0127 | val_gwR2=0.7161 | Dry_Green_g:0.648, Dry_Dead_g:0.429, Dry_Clover_g:0.707, GDM_g:0.635, Dry_Total_g:0.652
# Epoch 39/40 | train_loss=0.0117 | val_gwR2=0.7201 | Dry_Green_g:0.657, Dry_Dead_g:0.429, Dry_Clover_g:0.705, GDM_g:0.646, Dry_Total_g:0.656
# Epoch 40/40 | train_loss=0.0117 | val_gwR2=0.7236 | Dry_Green_g:0.666, Dry_Dead_g:0.430, Dry_Clover_g:0.703, GDM_g:0.654, Dry_Total_g:0.659
# [Fold 2] Final val global weighted R² = 0.7236
# Saved final checkpoint: model_outputs/fold1_final.pth
# Fold 1 weighted R² = 0.7236
#
# ========== Fold 3 / 5 ==========
# Epoch 01/40 | train_loss=0.3269 | val_gwR2=-1.3668 | Dry_Green_g:-0.762, Dry_Dead_g:-1.325, Dry_Clover_g:-0.425, GDM_g:-1.669, Dry_Total_g:-2.577
# Epoch 02/40 | train_loss=0.1297 | val_gwR2=-1.3647 | Dry_Green_g:-0.759, Dry_Dead_g:-1.323, Dry_Clover_g:-0.423, GDM_g:-1.666, Dry_Total_g:-2.575
# Epoch 03/40 | train_loss=0.0847 | val_gwR2=-1.3617 | Dry_Green_g:-0.755, Dry_Dead_g:-1.321, Dry_Clover_g:-0.420, GDM_g:-1.662, Dry_Total_g:-2.571
# Epoch 04/40 | train_loss=0.3118 | val_gwR2=-1.3524 | Dry_Green_g:-0.744, Dry_Dead_g:-1.314, Dry_Clover_g:-0.416, GDM_g:-1.651, Dry_Total_g:-2.557
# Epoch 05/40 | train_loss=0.0799 | val_gwR2=-1.3392 | Dry_Green_g:-0.726, Dry_Dead_g:-1.302, Dry_Clover_g:-0.412, GDM_g:-1.633, Dry_Total_g:-2.538
# Epoch 06/40 | train_loss=0.0576 | val_gwR2=-1.3209 | Dry_Green_g:-0.693, Dry_Dead_g:-1.288, Dry_Clover_g:-0.403, GDM_g:-1.608, Dry_Total_g:-2.513
# Epoch 07/40 | train_loss=0.0422 | val_gwR2=-1.2948 | Dry_Green_g:-0.650, Dry_Dead_g:-1.269, Dry_Clover_g:-0.386, GDM_g:-1.572, Dry_Total_g:-2.477
# Epoch 08/40 | train_loss=0.0339 | val_gwR2=-1.2594 | Dry_Green_g:-0.602, Dry_Dead_g:-1.244, Dry_Clover_g:-0.360, GDM_g:-1.521, Dry_Total_g:-2.428
# Epoch 09/40 | train_loss=0.0312 | val_gwR2=-1.2135 | Dry_Green_g:-0.542, Dry_Dead_g:-1.213, Dry_Clover_g:-0.324, GDM_g:-1.453, Dry_Total_g:-2.363
# Epoch 10/40 | train_loss=0.0299 | val_gwR2=-1.1545 | Dry_Green_g:-0.469, Dry_Dead_g:-1.176, Dry_Clover_g:-0.275, GDM_g:-1.362, Dry_Total_g:-2.281
# Epoch 11/40 | train_loss=0.0246 | val_gwR2=-1.0818 | Dry_Green_g:-0.391, Dry_Dead_g:-1.128, Dry_Clover_g:-0.208, GDM_g:-1.247, Dry_Total_g:-2.178
# Epoch 12/40 | train_loss=0.0245 | val_gwR2=-0.9933 | Dry_Green_g:-0.307, Dry_Dead_g:-1.069, Dry_Clover_g:-0.125, GDM_g:-1.113, Dry_Total_g:-2.051
# Epoch 13/40 | train_loss=0.0274 | val_gwR2=-0.8907 | Dry_Green_g:-0.217, Dry_Dead_g:-1.000, Dry_Clover_g:-0.024, GDM_g:-0.958, Dry_Total_g:-1.903
# Epoch 14/40 | train_loss=0.0236 | val_gwR2=-0.7790 | Dry_Green_g:-0.133, Dry_Dead_g:-0.919, Dry_Clover_g:0.097, GDM_g:-0.787, Dry_Total_g:-1.741
# Epoch 15/40 | train_loss=0.0199 | val_gwR2=-0.6502 | Dry_Green_g:-0.051, Dry_Dead_g:-0.832, Dry_Clover_g:0.228, GDM_g:-0.609, Dry_Total_g:-1.549
# Epoch 16/40 | train_loss=0.0185 | val_gwR2=-0.5137 | Dry_Green_g:0.032, Dry_Dead_g:-0.734, Dry_Clover_g:0.355, GDM_g:-0.430, Dry_Total_g:-1.343
# Epoch 17/40 | train_loss=0.0176 | val_gwR2=-0.3785 | Dry_Green_g:0.112, Dry_Dead_g:-0.627, Dry_Clover_g:0.477, GDM_g:-0.263, Dry_Total_g:-1.138
# Epoch 18/40 | train_loss=0.0170 | val_gwR2=-0.2471 | Dry_Green_g:0.181, Dry_Dead_g:-0.521, Dry_Clover_g:0.581, GDM_g:-0.112, Dry_Total_g:-0.935
# Epoch 19/40 | train_loss=0.0155 | val_gwR2=-0.1223 | Dry_Green_g:0.249, Dry_Dead_g:-0.416, Dry_Clover_g:0.662, GDM_g:0.022, Dry_Total_g:-0.741
# Epoch 20/40 | train_loss=0.0156 | val_gwR2=-0.0022 | Dry_Green_g:0.303, Dry_Dead_g:-0.309, Dry_Clover_g:0.720, GDM_g:0.142, Dry_Total_g:-0.551
# Epoch 21/40 | train_loss=0.0150 | val_gwR2=0.1052 | Dry_Green_g:0.357, Dry_Dead_g:-0.213, Dry_Clover_g:0.756, GDM_g:0.249, Dry_Total_g:-0.382
# Epoch 22/40 | train_loss=0.0134 | val_gwR2=0.1962 | Dry_Green_g:0.398, Dry_Dead_g:-0.128, Dry_Clover_g:0.785, GDM_g:0.333, Dry_Total_g:-0.237
# Epoch 23/40 | train_loss=0.0137 | val_gwR2=0.2764 | Dry_Green_g:0.434, Dry_Dead_g:-0.053, Dry_Clover_g:0.803, GDM_g:0.411, Dry_Total_g:-0.110
# Epoch 24/40 | train_loss=0.0153 | val_gwR2=0.3459 | Dry_Green_g:0.466, Dry_Dead_g:0.010, Dry_Clover_g:0.807, GDM_g:0.472, Dry_Total_g:0.001
# Epoch 25/40 | train_loss=0.0146 | val_gwR2=0.4046 | Dry_Green_g:0.494, Dry_Dead_g:0.063, Dry_Clover_g:0.802, GDM_g:0.525, Dry_Total_g:0.095
# Epoch 26/40 | train_loss=0.0134 | val_gwR2=0.4558 | Dry_Green_g:0.516, Dry_Dead_g:0.097, Dry_Clover_g:0.796, GDM_g:0.566, Dry_Total_g:0.179
# Epoch 27/40 | train_loss=0.0139 | val_gwR2=0.4992 | Dry_Green_g:0.536, Dry_Dead_g:0.132, Dry_Clover_g:0.789, GDM_g:0.601, Dry_Total_g:0.250
# Epoch 28/40 | train_loss=0.0139 | val_gwR2=0.5361 | Dry_Green_g:0.551, Dry_Dead_g:0.165, Dry_Clover_g:0.781, GDM_g:0.629, Dry_Total_g:0.311
# Epoch 29/40 | train_loss=0.0132 | val_gwR2=0.5639 | Dry_Green_g:0.566, Dry_Dead_g:0.198, Dry_Clover_g:0.773, GDM_g:0.653, Dry_Total_g:0.355
# Epoch 30/40 | train_loss=0.0121 | val_gwR2=0.5906 | Dry_Green_g:0.578, Dry_Dead_g:0.220, Dry_Clover_g:0.765, GDM_g:0.672, Dry_Total_g:0.399
# Epoch 31/40 | train_loss=0.0124 | val_gwR2=0.6113 | Dry_Green_g:0.588, Dry_Dead_g:0.247, Dry_Clover_g:0.759, GDM_g:0.688, Dry_Total_g:0.432
# Epoch 32/40 | train_loss=0.0120 | val_gwR2=0.6260 | Dry_Green_g:0.594, Dry_Dead_g:0.262, Dry_Clover_g:0.753, GDM_g:0.700, Dry_Total_g:0.455
# Epoch 33/40 | train_loss=0.0114 | val_gwR2=0.6428 | Dry_Green_g:0.603, Dry_Dead_g:0.283, Dry_Clover_g:0.748, GDM_g:0.711, Dry_Total_g:0.483
# Epoch 34/40 | train_loss=0.0116 | val_gwR2=0.6551 | Dry_Green_g:0.610, Dry_Dead_g:0.294, Dry_Clover_g:0.743, GDM_g:0.720, Dry_Total_g:0.503
# Epoch 35/40 | train_loss=0.0118 | val_gwR2=0.6680 | Dry_Green_g:0.616, Dry_Dead_g:0.309, Dry_Clover_g:0.738, GDM_g:0.728, Dry_Total_g:0.524
# Epoch 36/40 | train_loss=0.0117 | val_gwR2=0.6753 | Dry_Green_g:0.620, Dry_Dead_g:0.317, Dry_Clover_g:0.734, GDM_g:0.734, Dry_Total_g:0.535
# Epoch 37/40 | train_loss=0.0118 | val_gwR2=0.6839 | Dry_Green_g:0.624, Dry_Dead_g:0.325, Dry_Clover_g:0.730, GDM_g:0.739, Dry_Total_g:0.550
# Epoch 38/40 | train_loss=0.0118 | val_gwR2=0.6934 | Dry_Green_g:0.628, Dry_Dead_g:0.335, Dry_Clover_g:0.728, GDM_g:0.744, Dry_Total_g:0.566
# Epoch 39/40 | train_loss=0.0114 | val_gwR2=0.7005 | Dry_Green_g:0.632, Dry_Dead_g:0.343, Dry_Clover_g:0.725, GDM_g:0.747, Dry_Total_g:0.578
# Epoch 40/40 | train_loss=0.0109 | val_gwR2=0.7049 | Dry_Green_g:0.634, Dry_Dead_g:0.348, Dry_Clover_g:0.723, GDM_g:0.750, Dry_Total_g:0.585
# [Fold 3] Final val global weighted R² = 0.7049
# Saved final checkpoint: model_outputs/fold2_final.pth
# Fold 2 weighted R² = 0.7049
#
# ========== Fold 4 / 5 ==========
# Epoch 01/40 | train_loss=0.3580 | val_gwR2=-2.2052 | Dry_Green_g:-1.284, Dry_Dead_g:-1.679, Dry_Clover_g:-0.332, GDM_g:-2.961, Dry_Total_g:-5.346
# Epoch 02/40 | train_loss=0.1281 | val_gwR2=-2.2034 | Dry_Green_g:-1.279, Dry_Dead_g:-1.676, Dry_Clover_g:-0.331, GDM_g:-2.956, Dry_Total_g:-5.345
# Epoch 03/40 | train_loss=0.0963 | val_gwR2=-2.2009 | Dry_Green_g:-1.272, Dry_Dead_g:-1.672, Dry_Clover_g:-0.330, GDM_g:-2.949, Dry_Total_g:-5.342
# Epoch 04/40 | train_loss=0.2296 | val_gwR2=-2.1957 | Dry_Green_g:-1.254, Dry_Dead_g:-1.661, Dry_Clover_g:-0.329, GDM_g:-2.935, Dry_Total_g:-5.338
# Epoch 05/40 | train_loss=0.0862 | val_gwR2=-2.1896 | Dry_Green_g:-1.224, Dry_Dead_g:-1.651, Dry_Clover_g:-0.327, GDM_g:-2.929, Dry_Total_g:-5.330
# Epoch 06/40 | train_loss=0.0540 | val_gwR2=-2.1812 | Dry_Green_g:-1.179, Dry_Dead_g:-1.637, Dry_Clover_g:-0.323, GDM_g:-2.926, Dry_Total_g:-5.318
# Epoch 07/40 | train_loss=0.0469 | val_gwR2=-2.1680 | Dry_Green_g:-1.115, Dry_Dead_g:-1.618, Dry_Clover_g:-0.317, GDM_g:-2.917, Dry_Total_g:-5.300
# Epoch 08/40 | train_loss=0.0365 | val_gwR2=-2.1486 | Dry_Green_g:-1.040, Dry_Dead_g:-1.591, Dry_Clover_g:-0.309, GDM_g:-2.898, Dry_Total_g:-5.272
# Epoch 09/40 | train_loss=0.0307 | val_gwR2=-2.1208 | Dry_Green_g:-0.932, Dry_Dead_g:-1.552, Dry_Clover_g:-0.298, GDM_g:-2.869, Dry_Total_g:-5.233
# Epoch 10/40 | train_loss=0.0280 | val_gwR2=-2.0823 | Dry_Green_g:-0.806, Dry_Dead_g:-1.495, Dry_Clover_g:-0.282, GDM_g:-2.825, Dry_Total_g:-5.175
# Epoch 11/40 | train_loss=0.0233 | val_gwR2=-2.0269 | Dry_Green_g:-0.650, Dry_Dead_g:-1.413, Dry_Clover_g:-0.261, GDM_g:-2.757, Dry_Total_g:-5.089
# Epoch 12/40 | train_loss=0.0233 | val_gwR2=-1.9544 | Dry_Green_g:-0.482, Dry_Dead_g:-1.275, Dry_Clover_g:-0.232, GDM_g:-2.659, Dry_Total_g:-4.974
# Epoch 13/40 | train_loss=0.0203 | val_gwR2=-1.8736 | Dry_Green_g:-0.375, Dry_Dead_g:-1.118, Dry_Clover_g:-0.192, GDM_g:-2.554, Dry_Total_g:-4.831
# Epoch 14/40 | train_loss=0.0188 | val_gwR2=-1.7891 | Dry_Green_g:-0.323, Dry_Dead_g:-0.970, Dry_Clover_g:-0.145, GDM_g:-2.455, Dry_Total_g:-4.665
# Epoch 15/40 | train_loss=0.0181 | val_gwR2=-1.7008 | Dry_Green_g:-0.296, Dry_Dead_g:-0.835, Dry_Clover_g:-0.100, GDM_g:-2.347, Dry_Total_g:-4.487
# Epoch 16/40 | train_loss=0.0176 | val_gwR2=-1.6099 | Dry_Green_g:-0.260, Dry_Dead_g:-0.721, Dry_Clover_g:-0.053, GDM_g:-2.234, Dry_Total_g:-4.305
# Epoch 17/40 | train_loss=0.0187 | val_gwR2=-1.5109 | Dry_Green_g:-0.221, Dry_Dead_g:-0.615, Dry_Clover_g:-0.013, GDM_g:-2.113, Dry_Total_g:-4.104
# Epoch 18/40 | train_loss=0.0169 | val_gwR2=-1.4062 | Dry_Green_g:-0.184, Dry_Dead_g:-0.510, Dry_Clover_g:0.023, GDM_g:-1.990, Dry_Total_g:-3.888
# Epoch 19/40 | train_loss=0.0157 | val_gwR2=-1.2971 | Dry_Green_g:-0.135, Dry_Dead_g:-0.407, Dry_Clover_g:0.059, GDM_g:-1.862, Dry_Total_g:-3.664
# Epoch 20/40 | train_loss=0.0141 | val_gwR2=-1.1773 | Dry_Green_g:-0.088, Dry_Dead_g:-0.314, Dry_Clover_g:0.094, GDM_g:-1.722, Dry_Total_g:-3.415
# Epoch 21/40 | train_loss=0.0143 | val_gwR2=-1.0464 | Dry_Green_g:-0.026, Dry_Dead_g:-0.209, Dry_Clover_g:0.127, GDM_g:-1.563, Dry_Total_g:-3.147
# Epoch 22/40 | train_loss=0.0145 | val_gwR2=-0.9124 | Dry_Green_g:0.040, Dry_Dead_g:-0.111, Dry_Clover_g:0.158, GDM_g:-1.408, Dry_Total_g:-2.870
# Epoch 23/40 | train_loss=0.0138 | val_gwR2=-0.7726 | Dry_Green_g:0.112, Dry_Dead_g:-0.021, Dry_Clover_g:0.183, GDM_g:-1.241, Dry_Total_g:-2.581
# Epoch 24/40 | train_loss=0.0134 | val_gwR2=-0.6228 | Dry_Green_g:0.190, Dry_Dead_g:0.072, Dry_Clover_g:0.211, GDM_g:-1.071, Dry_Total_g:-2.269
# Epoch 25/40 | train_loss=0.0125 | val_gwR2=-0.4763 | Dry_Green_g:0.249, Dry_Dead_g:0.150, Dry_Clover_g:0.241, GDM_g:-0.899, Dry_Total_g:-1.962
# Epoch 26/40 | train_loss=0.0117 | val_gwR2=-0.3346 | Dry_Green_g:0.319, Dry_Dead_g:0.233, Dry_Clover_g:0.274, GDM_g:-0.725, Dry_Total_g:-1.671
# Epoch 27/40 | train_loss=0.0128 | val_gwR2=-0.2026 | Dry_Green_g:0.376, Dry_Dead_g:0.289, Dry_Clover_g:0.299, GDM_g:-0.573, Dry_Total_g:-1.393
# Epoch 28/40 | train_loss=0.0121 | val_gwR2=-0.0898 | Dry_Green_g:0.433, Dry_Dead_g:0.350, Dry_Clover_g:0.324, GDM_g:-0.429, Dry_Total_g:-1.163
# Epoch 29/40 | train_loss=0.0116 | val_gwR2=0.0234 | Dry_Green_g:0.482, Dry_Dead_g:0.405, Dry_Clover_g:0.343, GDM_g:-0.303, Dry_Total_g:-0.924
# Epoch 30/40 | train_loss=0.0111 | val_gwR2=0.1263 | Dry_Green_g:0.531, Dry_Dead_g:0.441, Dry_Clover_g:0.353, GDM_g:-0.171, Dry_Total_g:-0.712
# Epoch 31/40 | train_loss=0.0105 | val_gwR2=0.2168 | Dry_Green_g:0.570, Dry_Dead_g:0.483, Dry_Clover_g:0.363, GDM_g:-0.068, Dry_Total_g:-0.520
# Epoch 32/40 | train_loss=0.0109 | val_gwR2=0.2958 | Dry_Green_g:0.606, Dry_Dead_g:0.517, Dry_Clover_g:0.375, GDM_g:0.025, Dry_Total_g:-0.355
# Epoch 33/40 | train_loss=0.0105 | val_gwR2=0.3678 | Dry_Green_g:0.638, Dry_Dead_g:0.540, Dry_Clover_g:0.387, GDM_g:0.115, Dry_Total_g:-0.205
# Epoch 34/40 | train_loss=0.0104 | val_gwR2=0.4277 | Dry_Green_g:0.662, Dry_Dead_g:0.560, Dry_Clover_g:0.391, GDM_g:0.187, Dry_Total_g:-0.079
# Epoch 35/40 | train_loss=0.0109 | val_gwR2=0.4852 | Dry_Green_g:0.683, Dry_Dead_g:0.575, Dry_Clover_g:0.399, GDM_g:0.253, Dry_Total_g:0.043
# Epoch 36/40 | train_loss=0.0099 | val_gwR2=0.5289 | Dry_Green_g:0.699, Dry_Dead_g:0.582, Dry_Clover_g:0.407, GDM_g:0.311, Dry_Total_g:0.134
# Epoch 37/40 | train_loss=0.0103 | val_gwR2=0.5664 | Dry_Green_g:0.714, Dry_Dead_g:0.587, Dry_Clover_g:0.411, GDM_g:0.360, Dry_Total_g:0.212
# Epoch 38/40 | train_loss=0.0115 | val_gwR2=0.6010 | Dry_Green_g:0.727, Dry_Dead_g:0.590, Dry_Clover_g:0.414, GDM_g:0.404, Dry_Total_g:0.285
# Epoch 39/40 | train_loss=0.0100 | val_gwR2=0.6284 | Dry_Green_g:0.736, Dry_Dead_g:0.590, Dry_Clover_g:0.417, GDM_g:0.439, Dry_Total_g:0.343
# Epoch 40/40 | train_loss=0.0096 | val_gwR2=0.6525 | Dry_Green_g:0.744, Dry_Dead_g:0.587, Dry_Clover_g:0.421, GDM_g:0.471, Dry_Total_g:0.393
# [Fold 4] Final val global weighted R² = 0.6525
# Saved final checkpoint: model_outputs/fold3_final.pth
# Fold 3 weighted R² = 0.6525
#
# ========== Fold 5 / 5 ==========
# Epoch 01/40 | train_loss=0.3447 | val_gwR2=-1.5706 | Dry_Green_g:-0.801, Dry_Dead_g:-0.953, Dry_Clover_g:-0.601, GDM_g:-2.175, Dry_Total_g:-2.897
# Epoch 02/40 | train_loss=0.1320 | val_gwR2=-1.5695 | Dry_Green_g:-0.799, Dry_Dead_g:-0.950, Dry_Clover_g:-0.599, GDM_g:-2.173, Dry_Total_g:-2.896
# Epoch 03/40 | train_loss=0.0824 | val_gwR2=-1.5675 | Dry_Green_g:-0.795, Dry_Dead_g:-0.947, Dry_Clover_g:-0.596, GDM_g:-2.171, Dry_Total_g:-2.894
# Epoch 04/40 | train_loss=0.2938 | val_gwR2=-1.5605 | Dry_Green_g:-0.782, Dry_Dead_g:-0.939, Dry_Clover_g:-0.594, GDM_g:-2.161, Dry_Total_g:-2.885
# Epoch 05/40 | train_loss=0.0871 | val_gwR2=-1.5495 | Dry_Green_g:-0.760, Dry_Dead_g:-0.931, Dry_Clover_g:-0.593, GDM_g:-2.145, Dry_Total_g:-2.871
# Epoch 06/40 | train_loss=0.0578 | val_gwR2=-1.5326 | Dry_Green_g:-0.725, Dry_Dead_g:-0.921, Dry_Clover_g:-0.589, GDM_g:-2.119, Dry_Total_g:-2.850
# Epoch 07/40 | train_loss=0.0382 | val_gwR2=-1.5072 | Dry_Green_g:-0.678, Dry_Dead_g:-0.908, Dry_Clover_g:-0.580, GDM_g:-2.082, Dry_Total_g:-2.818
# Epoch 08/40 | train_loss=0.0339 | val_gwR2=-1.4710 | Dry_Green_g:-0.616, Dry_Dead_g:-0.897, Dry_Clover_g:-0.567, GDM_g:-2.030, Dry_Total_g:-2.771
# Epoch 09/40 | train_loss=0.0319 | val_gwR2=-1.4204 | Dry_Green_g:-0.534, Dry_Dead_g:-0.881, Dry_Clover_g:-0.549, GDM_g:-1.957, Dry_Total_g:-2.705
# Epoch 10/40 | train_loss=0.0274 | val_gwR2=-1.3561 | Dry_Green_g:-0.444, Dry_Dead_g:-0.862, Dry_Clover_g:-0.522, GDM_g:-1.866, Dry_Total_g:-2.618
# Epoch 11/40 | train_loss=0.0266 | val_gwR2=-1.2735 | Dry_Green_g:-0.347, Dry_Dead_g:-0.843, Dry_Clover_g:-0.488, GDM_g:-1.746, Dry_Total_g:-2.503
# Epoch 12/40 | train_loss=0.0225 | val_gwR2=-1.1674 | Dry_Green_g:-0.248, Dry_Dead_g:-0.814, Dry_Clover_g:-0.444, GDM_g:-1.597, Dry_Total_g:-2.350
# Epoch 13/40 | train_loss=0.0217 | val_gwR2=-1.0441 | Dry_Green_g:-0.150, Dry_Dead_g:-0.780, Dry_Clover_g:-0.390, GDM_g:-1.425, Dry_Total_g:-2.169
# Epoch 14/40 | train_loss=0.0193 | val_gwR2=-0.9006 | Dry_Green_g:-0.047, Dry_Dead_g:-0.741, Dry_Clover_g:-0.329, GDM_g:-1.231, Dry_Total_g:-1.954
# Epoch 15/40 | train_loss=0.0189 | val_gwR2=-0.7424 | Dry_Green_g:0.034, Dry_Dead_g:-0.689, Dry_Clover_g:-0.263, GDM_g:-1.035, Dry_Total_g:-1.706
# Epoch 16/40 | train_loss=0.0182 | val_gwR2=-0.5703 | Dry_Green_g:0.099, Dry_Dead_g:-0.631, Dry_Clover_g:-0.198, GDM_g:-0.828, Dry_Total_g:-1.428
# Epoch 17/40 | train_loss=0.0190 | val_gwR2=-0.4025 | Dry_Green_g:0.151, Dry_Dead_g:-0.570, Dry_Clover_g:-0.120, GDM_g:-0.630, Dry_Total_g:-1.156
# Epoch 18/40 | train_loss=0.0181 | val_gwR2=-0.2325 | Dry_Green_g:0.194, Dry_Dead_g:-0.509, Dry_Clover_g:-0.052, GDM_g:-0.443, Dry_Total_g:-0.873
# Epoch 19/40 | train_loss=0.0182 | val_gwR2=-0.0727 | Dry_Green_g:0.239, Dry_Dead_g:-0.442, Dry_Clover_g:0.012, GDM_g:-0.270, Dry_Total_g:-0.606
# Epoch 20/40 | train_loss=0.0163 | val_gwR2=0.0685 | Dry_Green_g:0.268, Dry_Dead_g:-0.377, Dry_Clover_g:0.070, GDM_g:-0.108, Dry_Total_g:-0.373
# Epoch 21/40 | train_loss=0.0164 | val_gwR2=0.2033 | Dry_Green_g:0.304, Dry_Dead_g:-0.313, Dry_Clover_g:0.123, GDM_g:0.045, Dry_Total_g:-0.150
# Epoch 22/40 | train_loss=0.0194 | val_gwR2=0.3164 | Dry_Green_g:0.330, Dry_Dead_g:-0.254, Dry_Clover_g:0.160, GDM_g:0.169, Dry_Total_g:0.039
# Epoch 23/40 | train_loss=0.0186 | val_gwR2=0.4085 | Dry_Green_g:0.343, Dry_Dead_g:-0.201, Dry_Clover_g:0.185, GDM_g:0.275, Dry_Total_g:0.193
# Epoch 24/40 | train_loss=0.0177 | val_gwR2=0.4723 | Dry_Green_g:0.353, Dry_Dead_g:-0.154, Dry_Clover_g:0.201, GDM_g:0.365, Dry_Total_g:0.293
# Epoch 25/40 | train_loss=0.0158 | val_gwR2=0.5245 | Dry_Green_g:0.364, Dry_Dead_g:-0.117, Dry_Clover_g:0.204, GDM_g:0.436, Dry_Total_g:0.377
# Epoch 26/40 | train_loss=0.0140 | val_gwR2=0.5730 | Dry_Green_g:0.377, Dry_Dead_g:-0.082, Dry_Clover_g:0.198, GDM_g:0.493, Dry_Total_g:0.458
# Epoch 27/40 | train_loss=0.0147 | val_gwR2=0.6060 | Dry_Green_g:0.387, Dry_Dead_g:-0.052, Dry_Clover_g:0.193, GDM_g:0.538, Dry_Total_g:0.510
# Epoch 28/40 | train_loss=0.0134 | val_gwR2=0.6284 | Dry_Green_g:0.398, Dry_Dead_g:-0.023, Dry_Clover_g:0.186, GDM_g:0.569, Dry_Total_g:0.545
# Epoch 29/40 | train_loss=0.0129 | val_gwR2=0.6452 | Dry_Green_g:0.404, Dry_Dead_g:0.007, Dry_Clover_g:0.178, GDM_g:0.592, Dry_Total_g:0.572
# Epoch 30/40 | train_loss=0.0133 | val_gwR2=0.6613 | Dry_Green_g:0.412, Dry_Dead_g:0.037, Dry_Clover_g:0.165, GDM_g:0.613, Dry_Total_g:0.598
# Epoch 31/40 | train_loss=0.0126 | val_gwR2=0.6736 | Dry_Green_g:0.417, Dry_Dead_g:0.059, Dry_Clover_g:0.150, GDM_g:0.627, Dry_Total_g:0.619
# Epoch 32/40 | train_loss=0.0132 | val_gwR2=0.6809 | Dry_Green_g:0.423, Dry_Dead_g:0.078, Dry_Clover_g:0.136, GDM_g:0.639, Dry_Total_g:0.630
# Epoch 33/40 | train_loss=0.0120 | val_gwR2=0.6871 | Dry_Green_g:0.425, Dry_Dead_g:0.100, Dry_Clover_g:0.119, GDM_g:0.646, Dry_Total_g:0.640
# Epoch 34/40 | train_loss=0.0113 | val_gwR2=0.6930 | Dry_Green_g:0.428, Dry_Dead_g:0.115, Dry_Clover_g:0.096, GDM_g:0.654, Dry_Total_g:0.651
# Epoch 35/40 | train_loss=0.0122 | val_gwR2=0.6960 | Dry_Green_g:0.431, Dry_Dead_g:0.132, Dry_Clover_g:0.084, GDM_g:0.658, Dry_Total_g:0.656
# Epoch 36/40 | train_loss=0.0125 | val_gwR2=0.6982 | Dry_Green_g:0.432, Dry_Dead_g:0.148, Dry_Clover_g:0.069, GDM_g:0.661, Dry_Total_g:0.661
# Epoch 37/40 | train_loss=0.0123 | val_gwR2=0.6997 | Dry_Green_g:0.431, Dry_Dead_g:0.160, Dry_Clover_g:0.050, GDM_g:0.663, Dry_Total_g:0.664
# Epoch 38/40 | train_loss=0.0117 | val_gwR2=0.7008 | Dry_Green_g:0.432, Dry_Dead_g:0.170, Dry_Clover_g:0.038, GDM_g:0.664, Dry_Total_g:0.667
# Epoch 39/40 | train_loss=0.0121 | val_gwR2=0.7017 | Dry_Green_g:0.432, Dry_Dead_g:0.179, Dry_Clover_g:0.030, GDM_g:0.665, Dry_Total_g:0.669
# Epoch 40/40 | train_loss=0.0124 | val_gwR2=0.7024 | Dry_Green_g:0.433, Dry_Dead_g:0.186, Dry_Clover_g:0.022, GDM_g:0.666, Dry_Total_g:0.670
# [Fold 5] Final val global weighted R² = 0.7024
# Saved final checkpoint: model_outputs/fold4_final.pth
# Fold 4 weighted R² = 0.7024
#
# Average weighted R²: 0.7098
#
# Overall OOF Global Weighted R²: 0.7263
#
# Per-target OOF R²:
# Dry_Green_g: 0.6572
# Dry_Dead_g: 0.3901
# Dry_Clover_g: 0.3895
# GDM_g: 0.7048
# Dry_Total_g: 0.6354

# %%
from google.colab import files

# !zip -r model_outputs.zip /content/model_outputs
files.download('model_outputs.zip')
# Out:
#   adding: content/model_outputs/ (stored 0%)
#   adding: content/model_outputs/fold4_final.pth (deflated 7%)
#   adding: content/model_outputs/fold3_final.pth (deflated 7%)
#   adding: content/model_outputs/fold2_final.pth (deflated 7%)
#   adding: content/model_outputs/fold0_final.pth (deflated 7%)
#   adding: content/model_outputs/fold1_final.pth (deflated 7%)
